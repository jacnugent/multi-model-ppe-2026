# %% [markdown]
# # For the one that meets PD LWP constraints, which constraint DOES it violate?
# Reviewer comment

# %%
import pickle
import glob
import sys
sys.path.append("/glade/work/jnug/codes/e3sm-ppe-aci/analysis/python")
import xarray as xr
import numpy as np
import multi_ppe_constraint_rev as mpc
import matplotlib.pyplot as plt

# %%
main_path = "/glade/u/home/jnug/work/multi_PPE_data/"
pickle_path = main_path + "pickle_jar/"
file_path = main_path + "annual_means/"

# %%
# constraints - 5% LWP & da/dlwp & pd-pi nd

ppe = "GA7.1"

with open(pickle_path + f"{ppe}_constrained_members_dict_error_tol_0.05.pickle", "rb") as handle:
    err05_dict = pickle.load(handle)
    
dadlwp_meet = err05_dict["dadlwp"]["match"]
lwp_meet = err05_dict["LWP_pd"]["match"]
dnd_meet = err05_dict["delta_Nd_pipd"]["match"]

good = [x for x in dnd_meet if (x in dadlwp_meet and x in lwp_meet)]

# %%
# GA7.1 

ds = xr.open_dataset(file_path + "GA7.1_data_annual_means.nc")

with open(pickle_path + "PPE_dadlwp_dict.pickle", "rb") as handle:
    ppe_dadlwp_dict = pickle.load(handle)
ds = ds.assign({"dadlwp": ppe_dadlwp_dict["GA7.1"].rename({"LWP_pd_masked", "dadlwp"})})

# %%
# get the ones that meet PD LWP
dlwp_goodpd = ds["delta_LWP"].sel(member=err05_dict["LWP_pd"]["match"])

# %%
# find the bad guy
dlwp_goodpd.where(dlwp_goodpd == dlwp_goodpd.min(), drop=True).member
# Out:
# <xarray.DataArray 'member' (member: 1)> Size: 4B
# array([65], dtype=int32)
# Coordinates:
#   * member   (member) int32 4B 65

# %%
65 in err05_dict["dadlwp"]["match"]
# Out:
# True

# %%
# 65 in err30_dict["delta_Nd_hem"]["match"]
65 in err05_dict["delta_Nd_pipd"]["match"]
# Out:
# False

# %%
65 in err05_dict["LWP_pd"]["match"]
# Out:
# True

# %%
# what about the min?
ds["delta_LWP"].where(ds["delta_LWP"] == ds["delta_LWP"].min(), drop=True).member
# Out:
# <xarray.DataArray 'member' (member: 1)> Size: 4B
# array([207], dtype=int32)
# Coordinates:
#   * member   (member) int32 4B 207

# %%
print(207 in err05_dict["dadlwp"]["match"])
print(207 in err05_dict["delta_Nd_pipd"]["match"])
print(207 in err05_dict["LWP_pd"]["match"])
# Out:
# False
# True
# False
